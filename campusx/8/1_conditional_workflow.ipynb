# %%
# quaderatic equation solving workflow

from langgraph.graph import StateGraph,START,END
from typing import TypedDict

# %%
class Coefficients(TypedDict):
    a: float
    b: float
    c: float
    
    equation: str
    discriminator: float
    result:str

# %%
graph=StateGraph(Coefficients)

# %%
def show_equation(state: Coefficients) -> Coefficients:
    equation=f{state['a']}x^2 + {state['b']}x + {state['c']} 
    
    return {'equation':equation}

def calculate_discriminator(state: Coefficients) -> Coefficients:

# %%
graph.add_node('show_equation',show_equation)
graph.add_node('calculate_discriminator',calculate_discriminator)
